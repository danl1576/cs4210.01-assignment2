# %%
#-------------------------------------------------------------------------
# AUTHOR: Daniela Lopez
# FILENAME: knn.py
# SPECIFICATION: Assignment #2
# FOR: CS 4210- Assignment #2
# TIME SPENT: 25 hours
#-----------------------------------------------------------*/

#IMPORTANT NOTE: DO NOT USE ANY ADVANCED PYTHON LIBRARY TO COMPLETE THIS CODE SUCH AS numpy OR pandas. You have to work here only with standard vectors and arrays

#importing some Python libraries
from sklearn.neighbors import KNeighborsClassifier
import csv
tpn = 0
db = []

#reading the data in a csv file
with open('binary_points.csv', 'r') as csvfile:
  reader = csv.reader(csvfile)
  for i, row in enumerate(reader):
      if i > 0: #skipping the header
         db.append (row)


#loop your data to allow each instance to be your test set
for i, instance in enumerate(db):

    #add the training features to the 2D array X removing the instance that will be used for testing in this iteration. For instance, X = [[1, 3], [2, 1,], ...]]. Convert each feature value to
    # float to avoid warning messages
    #--> add your Python code here
    X = []
    
    for list in db:
        for num, ints in enumerate(list[:2]):
            list[num] = float(ints)
        X.append(list[:2]) 
        

    #transform the original training classes to numbers and add to the vector Y removing the instance that will be used for testing in this iteration. For instance, Y = [1, 2, ,...]. Convert each
    #  feature value to float to avoid warning messages
    #--> add your Python code here
    Y = []
    
    for list in db:
        tempList = []
        for labels in list[2:]:
            if labels == "-":
                tempList.append(1.0)
            if labels == "+":
                tempList.append(2.0)
            
        Y.append(tempList) 

    #store the test sample of this iteration in the vector testSample
    #--> add your Python code here
    testSample = []
    
    testSample.append(instance[:2])
    
    #fitting the knn to the data
    clf = KNeighborsClassifier(n_neighbors=1, p=2)
    clf = clf.fit(X, Y)

    #use your test sample in this iteration to make the class prediction. For instance:
    #class_predicted = clf.predict([[1, 2]])[0]
    #--> add your Python code here
    class_predicted = []
    
    for row in X:
        temp = clf.predict(testSample)[0]
        class_predicted.append(temp)

    #compare the prediction with the true label of the test instance to start calculating the error rate.
    #--> add your Python code here

    for val in class_predicted:
        if class_predicted[val] == Y[val]:
            tpn+=1

       # accuracy = tpn / len(class_predicted)

#print the error rate
#--> add your Python code here

type(class_predicted)
# Out:
# C:\Users\danie\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-9e298bc2421d> in <module>
#      75
#      76     for val in class_predicted:
# ---> 77         if class_predicted[val] == Y[val]:
#      78             tpn+=1
#      79
#
# TypeError: list indices must be integers or slices, not numpy.float64
